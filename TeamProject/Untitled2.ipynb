# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine_data_preference.csv', encoding = 'cp949')
df.head()
# Out:
#    seq  gender  age     job  marital province  city choice
# 0  1.0    MALE  50대  중소기업직원  MARREID      부산시  해운대구      A
# 1  2.0  FEMALE  30대     연구원   SINGLE      경상도   하동군      D
# 2  3.0  FEMALE  30대     자영업  MARREID      부산시   사하구      B
# 3  4.0  FEMALE  40대     자영업  MARREID      부산시   사하구      D
# 4  5.0  FEMALE  40대      의사  MARREID      서울시   강남구      C

# %%
df.drop(['seq', 'province', 'city'], axis = 1, inplace = True)

# %%
df = df.dropna()
df = df[(df['gender'] == 'MALE') | (df['gender'] == 'FEMALE')]

# %%
qq_dict = {'MALE':1, 'FEMALE':0}
graph = list(map((lambda x: qq_dict[x]), df['gender'].to_list()))
graph[:10]
# Out:
# [1, 0, 0, 0, 0, 1, 1, 0, 1, 0]

# %%
choice = ['A', 'B', 'C', 'D', 'E','F', 'G', 'H']
male_result = list()
female_result = list()
for letter in choice:
    male_result.append(len(df[(df['choice'] == letter) & (df['gender'] == 'MALE')]))
    female_result.append(len(df[(df['choice'] == letter) & (df['gender'] != 'MALE')]))

# %%
plt.pie(male_result, labels=choice)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f98692480f0>,
#   <matplotlib.patches.Wedge at 0x7f9868ba3b38>,
#   <matplotlib.patches.Wedge at 0x7f9868ba3128>,
#   <matplotlib.patches.Wedge at 0x7f9868ba0828>,
#   <matplotlib.patches.Wedge at 0x7f9868ba0358>,
#   <matplotlib.patches.Wedge at 0x7f9868b9de48>,
#   <matplotlib.patches.Wedge at 0x7f9868b9d978>,
#   <matplotlib.patches.Wedge at 0x7f9868ba5a20>],
#  [Text(0.9869867298335319, 0.48565131023452524, 'A'),
#   Text(0.35083895816451216, 1.0425507303887136, 'B'),
#   Text(-0.18114317799059945, 1.0849825570337368, 'C'),
#   Text(-0.6833432814450046, 0.8619988165328148, 'D'),
#   Text(-1.0931587351669483, 0.12249073323397848, 'E'),
#   Text(-0.7553512734734773, -0.7996527081564824, 'F'),
#   Text(0.1480454382807251, -1.089991994559716, 'G'),
#   Text(0.9581581616598682, -0.5403081872825748, 'H')])

# %%
plt.pie(female_result, labels=choice)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f986b0ccdd8>,
#   <matplotlib.patches.Wedge at 0x7f986b0cc438>,
#   <matplotlib.patches.Wedge at 0x7f986b0cba58>,
#   <matplotlib.patches.Wedge at 0x7f986b0cb0b8>,
#   <matplotlib.patches.Wedge at 0x7f986b0c9c18>,
#   <matplotlib.patches.Wedge at 0x7f986b0c9748>,
#   <matplotlib.patches.Wedge at 0x7f986b0c9278>,
#   <matplotlib.patches.Wedge at 0x7f986b0cf7f0>],
#  [Text(1.0919093412036043, 0.13316903015457948, 'A'),
#   Text(0.7736844510475019, 0.7819286221947153, 'B'),
#   Text(-0.29706929222668044, 1.0591269213913597, 'C'),
#   Text(-1.099036088305703, 0.04603994571781145, 'D'),
#   Text(-0.33836593496923023, -1.046665416478637, 'E'),
#   Text(0.4236432131599307, -1.0151484758120506, 'F'),
#   Text(0.8017537673825874, -0.7531207715153181, 'G'),
#   Text(1.067052093438437, -0.26720746600469325, 'H')])

# %%
da = df[df['choice'] == 'A']
da['choice'] = 1
delse = df[df['choice'] != 'A']
print(len(da), len(delse))
# Out:
# 815 9139
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
delse = delse[:815]

# %%
delse['choice'] = 0
da = pd.concat([da, delse])

# %%
dummy = pd.get_dummies(df)
dummy.corr()
# Out:
#                  gender_FEMALE  gender_MALE   age_20대   age_30대   age_40대  \
# gender_FEMALE         1.000000    -1.000000 -0.004636  0.003716 -0.007983
# gender_MALE          -1.000000     1.000000  0.004636 -0.003716  0.007983
# age_20대              -0.004636     0.004636  1.000000 -0.282826 -0.316829
# age_30대               0.003716    -0.003716 -0.282826  1.000000 -0.371112
# age_40대              -0.007983     0.007983 -0.316829 -0.371112  1.000000
# age_50대               0.009247    -0.009247 -0.286170 -0.335200 -0.375500
# age_60대 이상           -0.004719     0.004719 -0.047199 -0.055286 -0.061933
# age_미상                0.011899    -0.011899 -0.012068 -0.014135 -0.015835
# job_공무원               0.001698    -0.001698 -0.051646  0.006670  0.022948
# job_교수               -0.008585     0.008585 -0.067957  0.025779  0.016393
# job_기자               -0.003630     0.003630 -0.077195  0.036174  0.012611
# job_미상                0.000204    -0.000204 -0.011016 -0.012903  0.015079
# job_벤처직원             -0.000817     0.000817 -0.049993  0.003961  0.015314
# job_변호사               0.001090    -0.001090 -0.058476  0.001686  0.038146
# job_연구원               0.001214    -0.001214 -0.061753  0.007937  0.036979
# job_의사               -0.002357     0.002357 -0.074740  0.033352  0.018870
# job_임시직               0.007665    -0.007665 -0.053412  0.020247  0.016413
# job_자영업               0.006635    -0.006635  0.172037 -0.050696 -0.060160
# job_중소기업직원            0.006164    -0.006164 -0.042113  0.011222  0.001864
# job_학생                0.002096    -0.002096  0.423407 -0.119751 -0.134148
# job_회사직원             -0.016689     0.016689 -0.045087  0.023541  0.015129
# marital_MARREID       0.012989    -0.012989 -0.014235  0.002492 -0.002623
# marital_SINGLE       -0.013119     0.013119  0.013442 -0.001873  0.002539
# marital_UNKNOWN       0.001462    -0.001462  0.010342 -0.007946  0.001115
# choice_A             -0.191398     0.191398 -0.043984 -0.072723 -0.064625
# choice_B              0.095558    -0.095558  0.249903 -0.044061 -0.107546
# choice_C              0.169221    -0.169221 -0.070504 -0.083312  0.079317
# choice_D              0.161718    -0.161718 -0.072009 -0.130340  0.062320
# choice_E              0.045731    -0.045731 -0.048425  0.340951 -0.150140
# choice_F             -0.175612     0.175612 -0.043313 -0.013812  0.143946
# choice_G             -0.074920     0.074920  0.044690 -0.016137  0.022671
# choice_H             -0.132481     0.132481 -0.028124 -0.010993  0.040344
#
#                   age_50대  age_60대 이상    age_미상   job_공무원    job_교수  ...  \
# gender_FEMALE    0.009247   -0.004719  0.011899  0.001698 -0.008585  ...
# gender_MALE     -0.009247    0.004719 -0.011899 -0.001698  0.008585  ...
# age_20대         -0.286170   -0.047199 -0.012068 -0.051646 -0.067957  ...
# age_30대         -0.335200   -0.055286 -0.014135  0.006670  0.025779  ...
# age_40대         -0.375500   -0.061933 -0.015835  0.022948  0.016393  ...
# age_50대          1.000000   -0.055940 -0.014303  0.016986  0.018042  ...
# age_60대 이상      -0.055940    1.000000 -0.002359 -0.000816  0.006107  ...
# age_미상          -0.014303   -0.002359  1.000000 -0.008253 -0.005742  ...
# job_공무원          0.016986   -0.000816 -0.008253  1.000000 -0.078574  ...
# job_교수           0.018042    0.006107 -0.005742 -0.078574  1.000000  ...
# job_기자           0.017264    0.013870  0.014012 -0.074221 -0.051644  ...
# job_미상           0.007564   -0.002153 -0.000551 -0.007533 -0.005242  ...
# job_벤처직원         0.025539    0.002088 -0.008334 -0.114041 -0.079351  ...
# job_변호사          0.010171    0.007941 -0.005528 -0.075640 -0.052631  ...
# job_연구원          0.010696   -0.003576 -0.005766 -0.078895 -0.054896  ...
# job_의사           0.018204   -0.012682 -0.005695 -0.077930 -0.054224  ...
# job_임시직          0.008004    0.014459  0.002250 -0.132939 -0.092500  ...
# job_자영업         -0.041551   -0.007344 -0.000327 -0.152993 -0.106454  ...
# job_중소기업직원       0.022538    0.014355 -0.008111 -0.110986 -0.077225  ...
# job_학생          -0.121166   -0.019985 -0.005110 -0.069915 -0.048648  ...
# job_회사직원         0.003739   -0.017473  0.033194 -0.110797 -0.077094  ...
# marital_MARREID  0.011766    0.004722  0.007538 -0.004681  0.001123  ...
# marital_SINGLE  -0.011634   -0.004456 -0.007477  0.005637 -0.000462  ...
# marital_UNKNOWN -0.001871   -0.003474 -0.000888 -0.012152 -0.008456  ...
# choice_A         0.177434    0.013664 -0.007334 -0.000844  0.030992  ...
# choice_B        -0.071530   -0.003994  0.024541  0.013133 -0.044372  ...
# choice_C         0.061966    0.011272 -0.008907 -0.062698  0.091932  ...
# choice_D         0.123402    0.032515 -0.011769  0.043005 -0.027171  ...
# choice_E        -0.132223   -0.022023 -0.010768  0.001037  0.021932  ...
# choice_F        -0.092855   -0.019648 -0.007823  0.028710  0.010129  ...
# choice_G        -0.045367   -0.015078  0.005188 -0.044520 -0.017814  ...
# choice_H        -0.006511   -0.000829  0.017147  0.011846 -0.054629  ...
#
#                  marital_SINGLE  marital_UNKNOWN  choice_A  choice_B  \
# gender_FEMALE         -0.013119         0.001462 -0.191398  0.095558
# gender_MALE            0.013119        -0.001462  0.191398 -0.095558
# age_20대                0.013442         0.010342 -0.043984  0.249903
# age_30대               -0.001873        -0.007946 -0.072723 -0.044061
# age_40대                0.002539         0.001115 -0.064625 -0.107546
# age_50대               -0.011634        -0.001871  0.177434 -0.071530
# age_60대 이상            -0.004456        -0.003474  0.013664 -0.003994
# age_미상                -0.007477        -0.000888 -0.007334  0.024541
# job_공무원                0.005637        -0.012152 -0.000844  0.013133
# job_교수                -0.000462        -0.008456  0.030992 -0.044372
# job_기자                -0.000200         0.005222  0.031477 -0.052419
# job_미상                -0.014925        -0.000811 -0.006695 -0.009291
# job_벤처직원              -0.015538        -0.012272  0.003408  0.007767
# job_변호사                0.008728         0.017829  0.031982 -0.038922
# job_연구원                0.008125        -0.008490  0.002345 -0.053894
# job_의사                -0.004961         0.004254  0.004007 -0.059967
# job_임시직               -0.000433         0.010090 -0.000308  0.022889
# job_자영업                0.013366        -0.001711 -0.020334  0.000380
# job_중소기업직원            -0.005604        -0.011943 -0.008807  0.024327
# job_학생                 0.003454         0.020374 -0.030896  0.150219
# job_회사직원              -0.010064         0.006785 -0.019605  0.010453
# marital_MARREID       -0.996940        -0.054151  0.012981 -0.008006
# marital_SINGLE         1.000000        -0.024075 -0.013739  0.008573
# marital_UNKNOWN       -0.024075         1.000000  0.009492 -0.007122
# choice_A              -0.013739         0.009492  1.000000 -0.123759
# choice_B               0.008573        -0.007122 -0.123759  1.000000
# choice_C               0.012007         0.004244 -0.108300 -0.150295
# choice_D              -0.032368         0.011222 -0.143107 -0.198599
# choice_E              -0.033113        -0.015855 -0.130933 -0.181705
# choice_F              -0.069749         0.007718 -0.095127 -0.132014
# choice_G               0.040512         0.006111 -0.100959 -0.140107
# choice_H               0.093504        -0.012883 -0.106384 -0.147637
#
#                  choice_C  choice_D  choice_E  choice_F  choice_G  choice_H
# gender_FEMALE    0.169221  0.161718  0.045731 -0.175612 -0.074920 -0.132481
# gender_MALE     -0.169221 -0.161718 -0.045731  0.175612  0.074920  0.132481
# age_20대         -0.070504 -0.072009 -0.048425 -0.043313  0.044690 -0.028124
# age_30대         -0.083312 -0.130340  0.340951 -0.013812 -0.016137 -0.010993
# age_40대          0.079317  0.062320 -0.150140  0.143946  0.022671  0.040344
# age_50대          0.061966  0.123402 -0.132223 -0.092855 -0.045367 -0.006511
# age_60대 이상       0.011272  0.032515 -0.022023 -0.019648 -0.015078 -0.000829
# age_미상          -0.008907 -0.011769 -0.010768 -0.007823  0.005188  0.017147
# job_공무원         -0.062698  0.043005  0.001037  0.028710 -0.044520  0.011846
# job_교수           0.091932 -0.027171  0.021932  0.010129 -0.017814 -0.054629
# job_기자           0.102972 -0.039745  0.009528 -0.002727  0.000801 -0.033413
# job_미상          -0.008130  0.000762 -0.009829  0.008362  0.021977  0.006197
# job_벤처직원        -0.056124  0.048293  0.004707  0.019744 -0.035302 -0.003938
# job_변호사          0.096869 -0.022434 -0.005606  0.002887 -0.009636 -0.041619
# job_연구원          0.120524 -0.031413  0.017377  0.028250 -0.022824 -0.049361
# job_의사           0.093938 -0.016251  0.015007 -0.002840  0.023914 -0.049401
# job_임시직         -0.026178 -0.043380 -0.014529 -0.026496  0.037593  0.059740
# job_자영업         -0.050407 -0.026093 -0.018517 -0.040936  0.091936  0.071239
# job_중소기업직원      -0.068201  0.054677 -0.007206  0.021943 -0.054949  0.023208
# job_학생          -0.040874 -0.014389 -0.013141 -0.043630  0.030946 -0.056589
# job_회사직원        -0.059494  0.044835  0.007926  0.012951 -0.026845  0.015051
# marital_MARREID -0.012325  0.031453  0.034314  0.069063 -0.040942 -0.092386
# marital_SINGLE   0.012007 -0.032368 -0.033113 -0.069749  0.040512  0.093504
# marital_UNKNOWN  0.004244  0.011222 -0.015855  0.007718  0.006111 -0.012883
# choice_A        -0.108300 -0.143107 -0.130933 -0.095127 -0.100959 -0.106384
# choice_B        -0.150295 -0.198599 -0.181705 -0.132014 -0.140107 -0.147637
# choice_C         1.000000 -0.173792 -0.159008 -0.115524 -0.122607 -0.129196
# choice_D        -0.173792  1.000000 -0.210112 -0.152652 -0.162011 -0.170718
# choice_E        -0.159008 -0.210112  1.000000 -0.139667 -0.148229 -0.156196
# choice_F        -0.115524 -0.152652 -0.139667  1.000000 -0.107693 -0.113480
# choice_G        -0.122607 -0.162011 -0.148229 -0.107693  1.000000 -0.120438
# choice_H        -0.129196 -0.170718 -0.156196 -0.113480 -0.120438  1.000000
#
# [32 rows x 32 columns]

# %%
from statsmodels.api import Logit
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
df = df[(df['age'] != '미상') & (df['job'] != '미상') & (df['marital'] != 'UNKNOWN')]

# %%
len(df)
# Out:
# 9930

# %%
df.head()
# Out:
#    gender  age     job  marital choice
# 0    MALE  50대  중소기업직원  MARREID      A
# 1  FEMALE  30대     연구원   SINGLE      D
# 2  FEMALE  30대     자영업  MARREID      B
# 3  FEMALE  40대     자영업  MARREID      D
# 4  FEMALE  40대      의사  MARREID      C

# %%
log_model = Logit.from_formula('''C(choice) ~ C(gender) + C(marital) + C(age) + C(job) ''', df)
log_result = log_model.fit()
print(log_result.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-c4c100198bb0> in <module>
#       1 log_model = Logit.from_formula('''C(choice) ~ C(gender) + C(marital) + C(age) + C(job) ''', df)
# ----> 2 log_result = log_model.fit()
#       3 print(log_result.summary())
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1832         bnryfit = super(Logit, self).fit(start_params=start_params,
#    1833                 method=method, maxiter=maxiter, full_output=full_output,
# -> 1834                 disp=disp, callback=callback, **kwargs)
#    1835
#    1836         discretefit = LogitResults(self, bnryfit)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     218         mlefit = super(DiscreteModel, self).fit(start_params=start_params,
#     219                 method=method, maxiter=maxiter, full_output=full_output,
# --> 220                 disp=disp, callback=callback, **kwargs)
#     221
#     222         return mlefit # up to subclasses to wrap results
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     464                                                        callback=callback,
#     465                                                        retall=retall,
# --> 466                                                        full_output=full_output)
#     467
#     468         # NOTE: this is for fit_regularized and should be generalized
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     189                             disp=disp, maxiter=maxiter, callback=callback,
#     190                             retall=retall, full_output=full_output,
# --> 191                             hess=hessian)
#     192
#     193         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit_newton(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess, ridge_factor)
#     277         oldparams = newparams
#     278         newparams = oldparams - np.dot(np.linalg.inv(H),
# --> 279                 score(oldparams))
#     280         if retall:
#     281             history.append(newparams)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in score(params, *args)
#     443             # TODO: why are score and hess positive?
#     444             def score(params, *args):
# --> 445                 return self.score(params, *args) / nobs
#     446
#     447             def hess(params, *args):
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py in score(self, params)
#    1775         X = self.exog
#    1776         L = self.cdf(np.dot(X,params))
# -> 1777         return np.dot(y - L,X)
#    1778
#    1779     def score_obs(self, params):
#
# ValueError: operands could not be broadcast together with shapes (9930,8) (9930,)

# %%
from sklearn.decomposition import PCA
import statsmodels.api as sm

# %%
df_x = df.drop('choice', axis = 1, inplace = False)
df_y = df['choice']
df_x = pd.get_dummies(df_x)
df_x.describe()
# Out:
#        gender_FEMALE  gender_MALE      age_20대      age_30대      age_40대  \
# count    9930.000000  9930.000000  9930.000000  9930.000000  9930.000000
# mean        0.595368     0.404632     0.194562     0.249245     0.293656
# std         0.490845     0.490845     0.395883     0.432598     0.455459
# min         0.000000     0.000000     0.000000     0.000000     0.000000
# 25%         0.000000     0.000000     0.000000     0.000000     0.000000
# 50%         1.000000     0.000000     0.000000     0.000000     0.000000
# 75%         1.000000     1.000000     0.000000     0.000000     1.000000
# max         1.000000     1.000000     1.000000     1.000000     1.000000
#
#            age_50대   age_60대 이상      job_공무원       job_교수       job_기자  ...  \
# count  9930.000000  9930.000000  9930.000000  9930.000000  9930.000000  ...
# mean      0.253374     0.009164     0.101712     0.051964     0.046425  ...
# std       0.434965     0.095295     0.302284     0.221965     0.210414  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#            job_변호사      job_연구원       job_의사      job_임시직      job_자영업  \
# count  9930.000000  9930.000000  9930.000000  9930.000000  9930.000000
# mean      0.048137     0.052367     0.051057     0.135247     0.171803
# std       0.214066     0.222776     0.220126     0.342004     0.377228
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#         job_중소기업직원      job_학생     job_회사직원  marital_MARREID  marital_SINGLE
# count  9930.000000  9930.00000  9930.000000      9930.000000     9930.000000
# mean      0.098590     0.04139     0.097784         0.692246        0.307754
# std       0.298126     0.19920     0.297038         0.461588        0.461588
# min       0.000000     0.00000     0.000000         0.000000        0.000000
# 25%       0.000000     0.00000     0.000000         0.000000        0.000000
# 50%       0.000000     0.00000     0.000000         1.000000        0.000000
# 75%       0.000000     0.00000     0.000000         1.000000        1.000000
# max       1.000000     1.00000     1.000000         1.000000        1.000000
#
# [8 rows x 21 columns]

# %%
df_x.columns

# %%
pca = PCA(n_components=len(df_x.columns))
nd_pca = pca.fit_transform(df_x)
df_pca = pd.DataFrame(nd_pca, columns = ['Prin' + str(x) for  x in range(len(df_x.columns))])

# %%
df_pca_stat = pd.DataFrame()
df_pca_stat['PrinNo'] = [i for i in range(1, len(df_x.columns)+1)]
df_pca_stat['EigenValues'] = pca.explained_variance_
df_pca_stat
