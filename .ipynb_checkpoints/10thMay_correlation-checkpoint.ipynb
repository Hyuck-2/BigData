# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
drink = {1:'소주', 2:'콜라', 3:'맥주', 4:'와인', 5:'주스'}

ds_raw = [[drink[1], drink[2], drink[3]],
         [drink[1], drink[2], drink[4]],
         [drink[1], drink[5]],
         [drink[2], drink[3]],
         [drink[1], drink[2], drink[3], drink[4]],
         [drink[5]]]
ds_raw
# Out:
# [['소주', '콜라', '맥주'],
#  ['소주', '콜라', '와인'],
#  ['소주', '주스'],
#  ['콜라', '맥주'],
#  ['소주', '콜라', '맥주', '와인'],
#  ['주스']]

# %%
enc = TransactionEncoder()
ds_raw_enc = enc.fit_transform(X = ds_raw)
df_asso = pd.DataFrame(ds_raw_enc, columns = enc.columns_)
df_asso.head()
# Out:
#       맥주     소주     와인     주스     콜라
# 0   True   True  False  False   True
# 1  False   True   True  False   True
# 2  False   True  False   True  False
# 3   True  False  False  False   True
# 4   True   True   True  False   True

# %%
min_support = 0.5
df_freq = apriori(df_asso, min_support = 0.5, use_colnames = True)
df_freq.round(3)
# Out:
#    support  itemsets
# 0    0.500      (맥주)
# 1    0.667      (소주)
# 2    0.667      (콜라)
# 3    0.500  (맥주, 콜라)
# 4    0.500  (소주, 콜라)

# %%
df_asso_rule = association_rules(df_freq, metric='confidence', min_threshold=0.5)
df_asso_rule.round(3)
# Out:
#   antecedents consequents  antecedent support  ...   lift  leverage  conviction
# 0        (맥주)        (콜라)               0.500  ...  1.500     0.167         inf
# 1        (콜라)        (맥주)               0.667  ...  1.500     0.167       2.000
# 2        (소주)        (콜라)               0.667  ...  1.125     0.056       1.333
# 3        (콜라)        (소주)               0.667  ...  1.125     0.056       1.333
#
# [4 rows x 9 columns]

# %%
df = pd.read_csv('상품구매.csv')
df.head()
# Out:
#      ID    PRODUCT
# 0  C-11   BAGUETTE
# 1  C-11    HERRING
# 2  C-11    AVOCADO
# 3  C-11  ARTICHOKE
# 4  C-11   HEINEKEN

# %%
member, product = df.iloc[1, [0, 1]]
print(member, product)
# Out:
# C-11 HERRING

# %%
shopping_list = dict()
for index in range(len(df)):
    member, product = df.iloc[index, [0, 1]]
    if member not in shopping_list:
        shopping_list[member] = [product]
    else:
        shopping_list[member].append(product)
df_now = pd.DataFrame()
for member in shopping_list:
    df_now[member] = shopping_list[member]
df_now = df_now.T

# %%
df_now.head()
# Out:
#              0            1        2  ...          4          5            6
# C-11  BAGUETTE      HERRING  AVOCADO  ...   HEINEKEN     APPLES  CORNED BEEF
# C-12   HERRING  CORNED BEEF   APPLES  ...      STEAK   SARDINES     HEINEKEN
# C-13  BAGUETTE     SARDINES   APPLES  ...    AVOCADO      STEAK    ICE CREAM
# C-14   HERRING  CORNED BEEF   OLIVES  ...     TURKEY       COKE       APPLES
# C-15    OLIVES      BOURBON     COKE  ...  ICE CREAM  ARTICHOKE          HAM
#
# [5 rows x 7 columns]

# %%
df_qq = [df_now.iloc[i] for i in range(len(df_now))]

# %%
enc = TransactionEncoder()
ds_raw_enc = enc.fit_transform(X = df_qq)
df_asso = pd.DataFrame(ds_raw_enc, columns = enc.columns_)
df_asso.head()
# Out:
#    APPLES  ARTICHOKE  AVOCADO  BAGUETTE  ...  SARDINES   SODA  STEAK  TURKEY
# 0    True       True     True      True  ...     False  False  False   False
# 1    True      False    False     False  ...      True  False   True   False
# 2    True      False     True      True  ...      True  False   True   False
# 3    True      False    False     False  ...     False  False  False    True
# 4   False       True    False     False  ...     False  False  False    True
#
# [5 rows x 19 columns]

# %%
min_support = 0.5
df_freq = apriori(df_asso, min_support = 0.5, use_colnames = True)
df_freq.round(3)
# Out:
#    support           itemsets
# 0     0.55          (BOURBON)
# 1     0.50             (COKE)
# 2     0.60         (HEINEKEN)
# 3     0.65           (OLIVES)
# 4     0.50  (OLIVES, BOURBON)

# %%
df_asso_rule = association_rules(df_freq, metric='confidence', min_threshold=0.5)
df_asso_rule.round(3)
# Out:
#   antecedents consequents  antecedent support  ...   lift  leverage  conviction
# 0    (OLIVES)   (BOURBON)                0.65  ...  1.399     0.142        1.95
# 1   (BOURBON)    (OLIVES)                0.55  ...  1.399     0.142        3.85
#
# [2 rows x 9 columns]
